# %% [markdown]
# # Step 1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Create Sample Movie Ratings Dataset

# %%
# Sample movie ratings dataset
np.random.seed(0)

data = {
    'Movie': [f'Movie {i}' for i in range(1, 101)],
    'Genre': np.random.choice(['Action', 'Comedy', 'Drama', 'Horror'], size=100),
    'Rating': np.random.uniform(1, 10, size=100)  # Ratings from 1 to 10
}

movies_df = pd.DataFrame(data)

print(movies_df.head())
# Out:
#      Movie   Genre    Rating
# 0  Movie 1  Action  6.131771
# 1  Movie 2  Horror  4.947414
# 2  Movie 3  Comedy  9.895365
# 3  Movie 4  Action  1.918403
# 4  Movie 5  Horror  2.879891

# %% [markdown]
# # Step 3: Visualize Distribution of Ratings (Histogram)

# %%
plt.figure(figsize=(10,6))
plt.hist(movies_df['Rating'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Step 4: Compare Average Ratings by Genre (Bar Chart)

# %%
# Calculate average rating per genre
avg_ratings = movies_df.groupby('Genre')['Rating'].mean().reset_index()

plt.figure(figsize=(8,6))
plt.bar(avg_ratings['Genre'], avg_ratings['Rating'], color='orange', edgecolor='black')
plt.title('Average Movie Rating by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
